# %% [markdown]
# d-sandbox
#
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png" alt="Databricks Learning" style="width: 600px">
# </div>

# %% [markdown]
# # Baseline Solution
#
# **Objective**: *Develop a baseline solution to a business problem.*
#
# In this lab, you will complete a series of exercises to develop a baseline solution to determine whether health tracker users are from the United States or Canada.

# %%
# %run "../../Includes/Classroom-Setup"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# Mounting course-specific datasets to <b>/mnt/training</b>...</br>Datasets are already mounted to <b>/mnt/training</b> from <b>s3a://databricks-corp-training/common</b>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[2]: DataFrame[]</div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res1: Boolean = false
# </div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">res2: Boolean = false
# </div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Exercise 1
#
# Summary: Randomly split health tracker users `dsfda.ht_users` into a training set (80 percent of users) and a test set (20 percent of users).

# %%
# %python
# ANSWER

# Load train_test_split
from sklearn.model_selection import train_test_split

# Split into training and test sets
ht_users_df = spark.sql("SELECT device_id, country FROM dsfda.ht_users").toPandas()
ht_users_train_df, ht_users_test_df = train_test_split(ht_users_df, test_size = 0.2, random_state = 42)

# Convert to Spark DataFrames
ht_users_train_sdf = spark.createDataFrame(ht_users_train_df)
ht_users_test_sdf = spark.createDataFrame(ht_users_test_df)

# Create tables for future SQL usage
ht_users_train_sdf.write.format("delta").mode("overwrite").save("/dsfda/ht_users_train")
spark.sql(
  "CREATE TABLE IF NOT EXISTS dsfda.ht_users_train USING DELTA LOCATION '/dsfda/ht_users_train'"
)
ht_users_test_sdf.write.format("delta").mode("overwrite").save("/dsfda/ht_users_test")
spark.sql(
  "CREATE TABLE IF NOT EXISTS dsfda.ht_users_test USING DELTA LOCATION '/dsfda/ht_users_test'"
)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[7]: DataFrame[]</div>

# %% [markdown]
# ## Exercise 2
#
# Summary: Identify what proportion of health tracker users are from the United States and Canada, respectively.

# %%
# %sql
-- ANSWER
SELECT b.country, b.grouped_total / a.total AS proportion
FROM (SELECT count(*) as total FROM dsfda.ht_users_train) a,
     (SELECT country, count(*) as grouped_total FROM dsfda.ht_users_train GROUP BY country) b
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>country</th><th>proportion</th></tr></thead><tbody><tr><td>United States</td><td>0.9770833333333333</td></tr><tr><td>Canada</td><td>0.022916666666666665</td></tr></tbody></table></div>

# %% [markdown]
# ## Exercise 3
#
# Summary: Apply a most-common case baseline solution to the test set and save to a new table.

# %%
# %sql
-- ANSWER
SELECT device_id, "United States" as predicted_country
FROM dsfda.ht_users_test
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>device_id</th><th>predicted_country</th></tr></thead><tbody><tr><td>f9a35106-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d621c744-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>f7a1da76-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fce425f2-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d8e444ca-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>0150756e-e48b-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>dfca7fca-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fc39b8a6-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>dc04d516-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>ee784c1e-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>002765c6-e48b-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>ea9e3c0c-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e7868b0a-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>faf1cc22-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fa8fdcce-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e1556300-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e0e8b6a6-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fda4901c-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fc6632f0-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>dd270d2e-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>f6158522-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d815d77a-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d868478a-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fb61ac22-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e8369ca2-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d7588e68-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fc8669e4-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fb8fd7aa-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e95deac2-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>f67f5088-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>ef878566-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d3f0a95e-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>dd926290-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>f267122e-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>f141a562-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d7be6792-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>eafece3c-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d7f79ecc-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e0ec8cfe-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e7021b5e-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e929a69a-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>ee3ed466-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fc12d38a-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e7ba3ce8-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>f0863dc2-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>ee90c6a4-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>f657eb92-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>d4ec4854-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>fb7307b0-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>e14977d4-e48a-11ea-8204-0242ac110002</td><td>United States</td></tr><tr><td>f100f026-e48a ...

# %% [markdown]
# ## Exercise 4
#
# Summary: Evaluate the baseline solution's accuracy on the test data.

# %%
# %sql
-- ANSWER
SELECT a.number_correct / b.number_total AS accuracy
FROM (SELECT count(*) AS number_correct 
      FROM dsfda.ht_users_test
      WHERE country = "United States") a,
     (SELECT count(*) AS number_total FROM dsfda.ht_users_test) b
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>accuracy</th></tr></thead><tbody><tr><td>0.97</td></tr></tbody></table></div>

# %% [markdown]
# Great job completing the Baseline Solution lab! Continue on with the lesson to learn about measuring solutions in real-world settings.

# %% [markdown]
# -sandbox
# &copy; 2021 Databricks, Inc. All rights reserved.<br/>
# Apache, Apache Spark, Spark and the Spark logo are trademarks of the <a href="http://www.apache.org/">Apache Software Foundation</a>.<br/>
# <br/>
# <a href="https://databricks.com/privacy-policy">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use">Terms of Use</a> | <a href="http://help.databricks.com/">Support</a>
